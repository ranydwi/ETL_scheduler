# %% [markdown]
# # Requirement for ETL automation using prefect
#
# - `pandas`: Data Manipulation
# - `pandas-gbq`: Pandas for google bigquery
#
# - `prefect`: Automation tools
# - `prefect-github`: Prefect extension for github
# - `prefect-gcp`: Prefect extension for Google BigQuery
#
# - `request`: For requesting
# - `tqdm`: Visualize the process progress

# %%
# Jika sudah ada tidak perlu diinstall
# %pip install pandas pandas-gbq
# %pip install requests tqdm

# %%
# Mandatory library
# 1.
# %pip install prefect
# Out:
# ...
#   Using cached aiosqlite-0.21.0-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached alembic-1.15.1-py3-none-any.whl.metadata (7.2 kB)
# ...
#   Using cached apprise-1.9.2-py3-none-any.whl.metadata (52 kB)
# ...
#   Using cached asgi_lifespan-2.1.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached asyncpg-0.30.0-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# ...
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached coolname-2.2.0-py2.py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached dateparser-1.2.1-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fastapi-0.115.11-py3-none-any.whl.metadata (27 kB)
# ...
#   Using cached fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached httpcore-1.0.7-py3-none-any.whl.metadata (21 kB)
# ...

# %%
# Mandatory Library
# 2.
# %pip install prefect-github prefect-gcp
# Out:
# ...
#   Using cached tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached google_api_core-2.24.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached google_cloud_core-2.4.3-py2.py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached protobuf-6.30.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# ...
#   Using cached grpcio-1.71.0-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# ...
#   Using cached grpcio_status-1.71.0-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# ...
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
# ...

# %%
# %pip install pandas-gbq
# Out:
# ...
#   Using cached pandas_gbq-0.28.0-py2.py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached db_dtypes-1.4.2-py2.py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached pyarrow-19.0.1-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# ...
#   Using cached pydata_google_auth-1.9.1-py2.py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached google_auth_oauthlib-1.2.1-py2.py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached google_cloud_bigquery-3.30.0-py2.py3-none-any.whl.metadata (7.9 kB)
# ...
# Using cached pandas_gbq-0.28.0-py2.py3-none-any.whl (37 kB)
# Using cached db_dtypes-1.4.2-py2.py3-none-any.whl (18 kB)
# Using cached google_auth_oauthlib-1.2.1-py2.py3-none-any.whl (24 kB)
# Using cached google_cloud_bigquery-3.30.0-py2.py3-none-any.whl (247 kB)
# Using cached pyarrow-19.0.1-cp312-cp312-win_amd64.whl (25.3 MB)
# Using cached pydata_google_auth-1.9.1-py2.py3-none-any.whl (15 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# List Library for requirement deployment

import pandas as pd
import pandas_gbq

import requests
import prefect
import prefect_github
import prefect_gcp

print(f'"{pd.__name__}=={pd.__version__}"')
print(f'"{pandas_gbq.__name__.replace("_", "-")}=={pandas_gbq.__version__}"')
print(f'"{requests.__name__}=={requests.__version__}"')
print(f'"{prefect.__name__}=={prefect.__version__}"')
print(f'"{prefect_github.__name__.replace("_", "-")}=={prefect_github.__version__}"')
print(f'"{prefect_gcp.__name__.replace("_", "-")}=={prefect_gcp.__version__}"')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       1 # List Library for requirement deployment
#       3 import pandas as pd
# ----> 4 import pandas_gbq
#       6 import requests
#       7 import prefect
#
# ModuleNotFoundError: No module named 'pandas_gbq'
